# %% [markdown]
# # Visual Studio Code Jupyter Notebook Support

# %%
msg = "Hello, Jupyter"
print(msg)

# %%
# !ls

# %%
import numpy as np
n = 200
fibonacchi = np.zeros((n))
fibonacchi[0] = 0
fibonacchi[1] = 1
index = 2
for index in range(2,n):
    fibonacchi[index] = fibonacchi[index - 1] + fibonacchi[index - 2]

# %%
import matplotlib.pyplot as plt
import numpy as np

x = np.linspace(0, 20, 100)
y = np.sin(x)
plt.plot(x, y)
plt.show()
